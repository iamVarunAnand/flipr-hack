# %%
import pandas as pd

# %%
df = pd.read_csv("../input/task2_test.csv")

# %%
df.head()
# Out:
#    people_ID Region  Gender Married  Children Occupation Mode_transport  \
# 0       5942  Delhi  Female     YES         2     Driver         Public
# 1      18664  Delhi    Male     YES         2      Legal           Walk
# 2       5603  Delhi  Female     YES         2      Sales            Car
# 3       5649  Delhi  Female     YES         2      Sales            Car
# 4       5099  Delhi  Female     YES         2   Business            Car
#
#   comorbidity  Age  Coma score  ... Platelets  HBB  d-dimer  Heart rate  \
# 0    Diabetes   52           3  ...       153  196      240          85
# 1    Diabetes   53          11  ...        95  138      241          81
# 2    Diabetes   35           9  ...        40  166      236          88
# 3        None   31          12  ...        78   83      211          87
# 4    Diabetes   51           6  ...       109  207      312          94
#
#    HDL cholesterol  Charlson Index  Blood Glucose  Insurance   salary  \
# ...

# %%
not_req = ["Designation", "Name", "cases/1M", "Deaths/1M"]
df = df.drop(not_req, axis = 1)
df.to_csv("../input/task2_test.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ea9249dcdd92> in <module>
#       1 not_req = ["Designation", "Name", "cases/1M", "Deaths/1M"]
# ----> 2 df = df.drop(not_req, axis = 1)
#       3 df.to_csv("../input/task2_test.csv", index = False)
#
# ~/environments/pyimagesearch/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# ~/environments/pyimagesearch/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# ...
